# %% [markdown]
# <a href="https://colab.research.google.com/github/msalmankhan03/Segmentation/blob/main/EARLY_SEGMENTATIONS_APROACHES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Threholding**

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("/content/salman.jpg", cv2.IMREAD_GRAYSCALE)
_, mask = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
plt.imshow(mask, cmap='gray')

# %% [markdown]
# **Edge-Based Segmentation**

# %%
edges = cv2.Canny(img, 100, 200)
plt.imshow(edges, cmap='gray')

# %% [markdown]
# **Region**-**based**-**segmentation**

# %%
import cv2
import numpy as np

img = cv2.imread("/content/salman.jpg")
Z = img.reshape((-1,3))
Z = np.float32(Z)

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K = 2
_, labels, centers = cv2.kmeans(Z, K, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
segmented = centers[labels.flatten()].reshape(img.shape)
plt.imshow(cv2.cvtColor(segmented, cv2.COLOR_BGR2RGB))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [55.312748..160.32794].
